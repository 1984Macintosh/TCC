# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from collections import defaultdict
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.utils.data as data_utils
from torchvision import datasets, transforms

# Device Config
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Fix random seeds for reproducibility
seed = 73
torch.manual_seed(seed)
np.random.seed(seed)

# Load CIFAR-10 dataset
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
    ]),
}

train_dataset = datasets.CIFAR10(root='data', train=True, download=True, transform=data_transforms['train'])
val_dataset = datasets.CIFAR10(root='data', train=False, download=True, transform=data_transforms['val'])

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

n_classes = 10  # CIFAR-10 has 10 classes

# Define the VIB model (DeepVIB)
class DeepVIB(nn.Module):
    def __init__(self, input_shape, output_shape, z_dim):
        super(DeepVIB, self).__init__()
        self.input_shape = input_shape
        self.output_shape = output_shape
        self.z_dim = z_dim

        # Build encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_shape, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(inplace=True)
        )
        self.fc_mu = nn.Linear(1024, self.z_dim)
        self.fc_std = nn.Linear(1024, self.z_dim)

        # Build decoder
        self.decoder = nn.Linear(self.z_dim, output_shape)

    def encode(self, x):
        x = self.encoder(x)
        return self.fc_mu(x), F.softplus(self.fc_std(x) - 5, beta=1)

    def decode(self, z):
        return self.decoder(z)

    def reparameterise(self, mu, std):
        eps = torch.randn_like(std)
        return mu + std * eps

    def forward(self, x):
        x_flat = x.view(x.size(0), -1)
        mu, std = self.encode(x_flat)
        z = self.reparameterise(mu, std)
        return self.decode(z), mu, std


# Hyperparameters
beta = 1e-3
z_dim = 256
epochs = 100
learning_rate = 1e-4
decay_rate = 0.97

# Initialize the model, optimizer, and learning rate scheduler
input_shape = 32 * 32 * 3  # CIFAR-10 image size is 32x32 with 3 color channels (RGB)
vib = DeepVIB(input_shape, n_classes, z_dim).to(device)
optimizer = torch.optim.Adam(vib.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=decay_rate)

# Loss function: Cross Entropy Loss (CE) + beta*KL divergence
def loss_function(y_pred, y, mu, std):
    CE = F.cross_entropy(y_pred, y, reduction='sum')
    KL = 0.5 * torch.sum(mu.pow(2) + std.pow(2) - 2 * std.log() - 1)
    return (beta * KL + CE) / y.size(0)

# Training loop
train_measures = defaultdict(list)
val_measures = defaultdict(list)
start_time = time.time()

for epoch in range(epochs):
    vib.train()
    epoch_start_time = time.time()

    train_loss = 0
    train_accuracy = 0
    for X, y in train_dataloader:
        X, y = X.to(device), y.to(device)

        vib.zero_grad()
        y_pred, mu, std = vib(X)
        loss = loss_function(y_pred, y, mu, std)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * X.size(0)
        y_pred_labels = torch.argmax(y_pred, dim=1)
        train_accuracy += (y_pred_labels == y).sum().item()

    train_measures['loss'].append(train_loss / len(train_dataloader.dataset))
    train_measures['accuracy'].append(train_accuracy / len(train_dataloader.dataset))

    # Validation loop
    vib.eval()
    val_loss = 0
    val_accuracy = 0
    with torch.no_grad():
        for X, y in val_dataloader:
            X, y = X.to(device), y.to(device)

            y_pred, mu, std = vib(X)
            loss = loss_function(y_pred, y, mu, std)
            val_loss += loss.item() * X.size(0)
            y_pred_labels = torch.argmax(y_pred, dim=1)
            val_accuracy += (y_pred_labels == y).sum().item()

    val_measures['loss'].append(val_loss / len(val_dataloader.dataset))
    val_measures['accuracy'].append(val_accuracy / len(val_dataloader.dataset))

    print(f"Epoch {epoch + 1}/{epochs} - "
          f"Train Loss: {train_measures['loss'][-1]:.4f}, "
          f"Train Accuracy: {train_measures['accuracy'][-1]:.4f}, "
          f"Val Loss: {val_measures['loss'][-1]:.4f}, "
          f"Val Accuracy: {val_measures['accuracy'][-1]:.4f}, "
          f"Time: {time.time() - epoch_start_time:.2f} seconds")

# Plotting the training and validation metrics
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_measures['loss'], label='Train Loss')
plt.plot(val_measures['loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_measures['accuracy'], label='Train Accuracy')
plt.plot(val_measures['accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# Testing the model
vib.eval()
test_accuracy = 0
all_preds = []
all_labels = []
with torch.no_grad():
    for X, y in val_dataloader:
        X, y = X.to(device), y.to(device)

        y_pred, mu, std = vib(X)
        y_pred_labels = torch.argmax(y_pred, dim=1)
        test_accuracy += (y_pred_labels == y).sum().item()
        all_preds.append(y_pred_labels.cpu().numpy())
        all_labels.append(y.cpu().numpy())

test_accuracy /= len(val_dataloader.dataset)
print(f"Test Accuracy: {test_accuracy:.4f}")

all_preds = np.concatenate(all_preds)
all_labels = np.concatenate(all_labels)

# Visualizing correctly classified images
correct_indices = np.where(all_preds == all_labels)[0]
incorrect_indices = np.where(all_preds != all_labels)[0]

def visualize_images(indices, title):
    plt.figure(figsize=(12, 12))
    for i, idx in enumerate(indices[:6]):
        img, label = val_dataset[idx]
        img = img.permute(1, 2, 0)  # Reshape for plotting
        img = img.numpy()
        img = img * np.array([0.247, 0.243, 0.261]) + np.array([0.4914, 0.4822, 0.4465])  # Unnormalize
        plt.subplot(2, 3, i + 1)
        plt.imshow(img)
        plt.title(f"Label: {label} | Pred: {all_preds[idx]}")
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# Display correct and incorrect classifications
visualize_images(correct_indices, "Correctly Classified Images")
visualize_images(incorrect_indices, "Incorrectly Classified Images")

# Confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

conf_matrix = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 59513433.84it/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Epoch 1/100 - Train Loss: 2.0250, Train Accuracy: 0.3291, Val Loss: 1.9801, Val Accuracy: 0.4128, Time: 86.98 seconds
# Epoch 2/100 - Train Loss: 1.7595, Train Accuracy: 0.4038, Val Loss: 1.9218, Val Accuracy: 0.4468, Time: 74.77 seconds
# Epoch 3/100 - Train Loss: 1.6695, Train Accuracy: 0.4303, Val Loss: 1.8727, Val Accuracy: 0.4689, Time: 73.45 seconds
# Epoch 4/100 - Train Loss: 1.6113, Train Accuracy: 0.4498, Val Loss: 1.8664, Val Accuracy: 0.4688, Time: 72.58 seconds
# Epoch 5/100 - Train Loss: 1.5651, Train Accuracy: 0.4672, Val Loss: 1.8538, Val Accuracy: 0.4728, Time: 73.15 seconds
# Epoch 6/100 - Train Loss: 1.5327, Train Accuracy: 0.4768, Val Loss: 1.8014, Val Accuracy: 0.4843, Time: 74.19 seconds
# Epoch 7/100 - Train Loss: 1.4999, Train Accuracy: 0.4902, Val Loss: 1.8073, Val Accuracy: 0.4995, Time: 74.69 seconds
# Epoch 8/100 - Train Loss: 1.4724, Train Accuracy: 0.4987, Val Loss: 1.7537, Val Accuracy: 0.4975, Time: 72.22 seconds
# Epoch 9/100 - Train Loss: 1.4614, Train Accuracy: 0.5070, Val Loss: 1.7888, Val Accuracy: 0.4873, Time: 73.39 seconds
# Epoch 10/100 - Train Loss: 1.4327, Train Accuracy: 0.5152, Val Loss: 1.7515, Val Accuracy: 0.4977, Time: 73.77 seconds
# Epoch 11/100 - Train Loss: 1.4198, Train Accuracy: 0.5191, Val Loss: 1.7209, Val Accuracy: 0.5016, Time: 73.19 seconds
# Epoch 12/100 - Train Loss: 1.4047, Train Accuracy: 0.5236, Val Loss: 1.7273, Val Accuracy: 0.5104, Time: 73.33 seconds
# Epoch 13/100 - Train Loss: 1.3868, Train Accuracy: 0.5320, Val Loss: 1.7468, Val Accuracy: 0.5040, Time: 73.92 seconds
# Epoch 14/100 - Train Loss: 1.3727, Train Accuracy: 0.5382, Val Loss: 1.7026, Val Accuracy: 0.5070, Time: 73.62 seconds
# Epoch 15/100 - Train Loss: 1.3606, Train Accuracy: 0.5415, Val Loss: 1.6711, Val Accuracy: 0.5104, Time: 72.94 seconds
# Epoch 16/100 - Train Loss: 1.3468, Train Accuracy: 0.5445, Val Loss: 1.6629, Val Accuracy: 0.5115, Time: 75.60 seconds
# Epoch 17/100 - Train Loss: 1.3365, Train Accuracy: 0.5489, Val Loss: 1.6882, Val Accuracy: 0.5205, Time: 73.91 seconds
# Epoch 18/100 - Train Loss: 1.3205, Train Accuracy: 0.5585, Val Loss: 1.6716, Val Accuracy: 0.5183, Time: 73.93 seconds
# Epoch 19/100 - Train Loss: 1.3105, Train Accuracy: 0.5576, Val Loss: 1.6498, Val Accuracy: 0.5303, Time: 72.94 seconds
# Epoch 20/100 - Train Loss: 1.2992, Train Accuracy: 0.5638, Val Loss: 1.6640, Val Accuracy: 0.5260, Time: 73.63 seconds
# Epoch 21/100 - Train Loss: 1.2870, Train Accuracy: 0.5683, Val Loss: 1.6682, Val Accuracy: 0.5178, Time: 73.29 seconds
# Epoch 22/100 - Train Loss: 1.2817, Train Accuracy: 0.5696, Val Loss: 1.6131, Val Accuracy: 0.5308, Time: 73.55 seconds
# Epoch 23/100 - Train Loss: 1.2703, Train Accuracy: 0.5730, Val Loss: 1.6078, Val Accuracy: 0.5293, Time: 72.36 seconds
# Epoch 24/100 - Train Loss: 1.2636, Train Accuracy: 0.5746, Val Loss: 1.6524, Val Accuracy: 0.5195, Time: 75.21 seconds
# Epoch 25/100 - Train Loss: 1.2576, Train Accuracy: 0.5809, Val Loss: 1.5859, Val Accuracy: 0.5426, Time: 73.61 seconds
# Epoch 26/100 - Train Loss: 1.2470, Train Accuracy: 0.5828, Val Loss: 1.5747, Val Accuracy: 0.5294, Time: 73.05 seconds
# Epoch 27/100 - Train Loss: 1.2276, Train Accuracy: 0.5913, Val Loss: 1.5790, Val Accuracy: 0.5294, Time: 73.06 seconds
# Epoch 28/100 - Train Loss: 1.2248, Train Accuracy: 0.5907, Val Loss: 1.5956, Val Accuracy: 0.5375, Time: 73.58 seconds
# Epoch 29/100 - Train Loss: 1.2115, Train Accuracy: 0.5950, Val Loss: 1.5850, Val Accuracy: 0.5314, Time: 73.61 seconds
# Epoch 30/100 - Train Loss: 1.2052, Train Accuracy: 0.5985, Val Loss: 1.6118, Val Accuracy: 0.5339, Time: 72.33 seconds
# Epoch 31/100 - Train Loss: 1.1925, Train Accuracy: 0.6015, Val Loss: 1.6073, Val Accuracy: 0.5321, Time: 73.11 seconds
# Epoch 32/100 - Train Loss: 1.1954, Train Accuracy: 0.6001, Val Loss: 1.5987, Val Accuracy: 0.5433, Time: 73.30 seconds
# Epoch 33/100 - Train Loss: 1.1838, Train Accuracy: 0.6058, Val Loss: 1.5656, Val Accuracy: 0.5380, Time: 72.75 seconds
# Epoch 34/100 - Train Loss: 1.1755, Train Accuracy: 0.6096, Val Loss: 1.5632, Val Accuracy: 0.5466, Time: 73.93 seconds
# Epoch 35/100 - Train Loss: 1.1665, Train Accuracy: 0.6125, Val Loss: 1.5505, Val Accuracy: 0.5413, Time: 74.22 seconds
# Epoch 36/100 - Train Loss: 1.1558, Train Accuracy: 0.6149, Val Loss: 1.6044, Val Accuracy: 0.5369, Time: 74.77 seconds
# Epoch 37/100 - Train Loss: 1.1529, Train Accuracy: 0.6188, Val Loss: 1.5383, Val Accuracy: 0.5462, Time: 74.81 seconds
# Epoch 38/100 - Train Loss: 1.1434, Train Accuracy: 0.6209, Val Loss: 1.5484, Val Accuracy: 0.5455, Time: 74.05 seconds
# Epoch 39/100 - Train Loss: 1.1366, Train Accuracy: 0.6226, Val Loss: 1.5669, Val Accuracy: 0.5477, Time: 73.40 seconds
# Epoch 40/100 - Train Loss: 1.1299, Train Accuracy: 0.6243, Val Loss: 1.5653, Val Accuracy: 0.5376, Time: 73.32 seconds
# Epoch 41/100 - Train Loss: 1.1227, Train Accuracy: 0.6278, Val Loss: 1.5596, Val Accuracy: 0.5442, Time: 73.63 seconds
# Epoch 42/100 - Train Loss: 1.1128, Train Accuracy: 0.6298, Val Loss: 1.5462, Val Accuracy: 0.5537, Time: 72.85 seconds
# Epoch 43/100 - Train Loss: 1.1083, Train Accuracy: 0.6318, Val Loss: 1.5339, Val Accuracy: 0.5485, Time: 73.86 seconds
# Epoch 44/100 - Train Loss: 1.1042, Train Accuracy: 0.6337, Val Loss: 1.5392, Val Accuracy: 0.5537, Time: 74.09 seconds
# Epoch 45/100 - Train Loss: 1.0997, Train Accuracy: 0.6353, Val Loss: 1.5443, Val Accuracy: 0.5493, Time: 73.61 seconds
# Epoch 46/100 - Train Loss: 1.0904, Train Accuracy: 0.6411, Val Loss: 1.5150, Val Accuracy: 0.5599, Time: 73.45 seconds
# Epoch 47/100 - Train Loss: 1.0832, Train Accuracy: 0.6401, Val Loss: 1.5244, Val Accuracy: 0.5529, Time: 74.23 seconds
# Epoch 48/100 - Train Loss: 1.0708, Train Accuracy: 0.6444, Val Loss: 1.5422, Val Accuracy: 0.5454, Time: 74.13 seconds
# Epoch 49/100 - Train Loss: 1.0696, Train Accuracy: 0.6476, Val Loss: 1.5317, Val Accuracy: 0.5565, Time: 74.08 seconds
# Epoch 50/100 - Train Loss: 1.0615, Train Accuracy: 0.6475, Val Loss: 1.5151, Val Accuracy: 0.5573, Time: 73.82 seconds
# Epoch 51/100 - Train Loss: 1.0559, Train Accuracy: 0.6510, Val Loss: 1.5138, Val Accuracy: 0.5639, Time: 74.71 seconds
# Epoch 52/100 - Train Loss: 1.0512, Train Accuracy: 0.6513, Val Loss: 1.5204, Val Accuracy: 0.5585, Time: 74.72 seconds
# Epoch 53/100 - Train Loss: 1.0405, Train Accuracy: 0.6549, Val Loss: 1.5008, Val Accuracy: 0.5724, Time: 75.31 seconds
# Epoch 54/100 - Train Loss: 1.0422, Train Accuracy: 0.6579, Val Loss: 1.5244, Val Accuracy: 0.5574, Time: 75.23 seconds
# Epoch 55/100 - Train Loss: 1.0297, Train Accuracy: 0.6604, Val Loss: 1.5137, Val Accuracy: 0.5551, Time: 73.75 seconds
# Epoch 56/100 - Train Loss: 1.0210, Train Accuracy: 0.6609, Val Loss: 1.5213, Val Accuracy: 0.5622, Time: 72.68 seconds
# Epoch 57/100 - Train Loss: 1.0115, Train Accuracy: 0.6651, Val Loss: 1.4955, Val Accuracy: 0.5663, Time: 73.15 seconds
# Epoch 58/100 - Train Loss: 1.0142, Train Accuracy: 0.6653, Val Loss: 1.4819, Val Accuracy: 0.5661, Time: 75.31 seconds
# Epoch 59/100 - Train Loss: 1.0035, Train Accuracy: 0.6696, Val Loss: 1.4988, Val Accuracy: 0.5636, Time: 73.41 seconds
# Epoch 60/100 - Train Loss: 1.0019, Train Accuracy: 0.6710, Val Loss: 1.5104, Val Accuracy: 0.5620, Time: 73.66 seconds
# Epoch 61/100 - Train Loss: 0.9914, Train Accuracy: 0.6719, Val Loss: 1.5153, Val Accuracy: 0.5628, Time: 73.98 seconds
# Epoch 62/100 - Train Loss: 0.9902, Train Accuracy: 0.6770, Val Loss: 1.4962, Val Accuracy: 0.5667, Time: 73.96 seconds
# Epoch 63/100 - Train Loss: 0.9831, Train Accuracy: 0.6760, Val Loss: 1.5006, Val Accuracy: 0.5677, Time: 73.53 seconds
# Epoch 64/100 - Train Loss: 0.9713, Train Accuracy: 0.6821, Val Loss: 1.4821, Val Accuracy: 0.5649, Time: 72.71 seconds
# Epoch 65/100 - Train Loss: 0.9681, Train Accuracy: 0.6827, Val Loss: 1.5031, Val Accuracy: 0.5588, Time: 73.01 seconds
# Epoch 66/100 - Train Loss: 0.9660, Train Accuracy: 0.6823, Val Loss: 1.5027, Val Accuracy: 0.5710, Time: 73.23 seconds
# Epoch 67/100 - Train Loss: 0.9617, Train Accuracy: 0.6840, Val Loss: 1.4711, Val Accuracy: 0.5729, Time: 72.75 seconds
# Epoch 68/100 - Train Loss: 0.9529, Train Accuracy: 0.6876, Val Loss: 1.5201, Val Accuracy: 0.5548, Time: 73.34 seconds
# Epoch 69/100 - Train Loss: 0.9492, Train Accuracy: 0.6906, Val Loss: 1.5035, Val Accuracy: 0.5571, Time: 73.19 seconds
# Epoch 70/100 - Train Loss: 0.9370, Train Accuracy: 0.6938, Val Loss: 1.4992, Val Accuracy: 0.5652, Time: 72.10 seconds
# Epoch 71/100 - Train Loss: 0.9320, Train Accuracy: 0.6942, Val Loss: 1.4927, Val Accuracy: 0.5703, Time: 73.17 seconds
# Epoch 72/100 - Train Loss: 0.9363, Train Accuracy: 0.6930, Val Loss: 1.5018, Val Accuracy: 0.5603, Time: 73.35 seconds
# Epoch 73/100 - Train Loss: 0.9267, Train Accuracy: 0.6971, Val Loss: 1.4920, Val Accuracy: 0.5723, Time: 72.33 seconds
# Epoch 74/100 - Train Loss: 0.9192, Train Accuracy: 0.6989, Val Loss: 1.4993, Val Accuracy: 0.5653, Time: 72.87 seconds
# Epoch 75/100 - Train Loss: 0.9156, Train Accuracy: 0.7005, Val Loss: 1.5011, Val Accuracy: 0.5630, Time: 73.27 seconds
# Epoch 76/100 - Train Loss: 0.9096, Train Accuracy: 0.6999, Val Loss: 1.5029, Val Accuracy: 0.5618, Time: 73.04 seconds
# Epoch 77/100 - Train Loss: 0.9053, Train Accuracy: 0.7033, Val Loss: 1.5106, Val Accuracy: 0.5619, Time: 73.07 seconds
# Epoch 78/100 - Train Loss: 0.9035, Train Accuracy: 0.7037, Val Loss: 1.5163, Val Accuracy: 0.5617, Time: 74.01 seconds
# Epoch 79/100 - Train Loss: 0.8959, Train Accuracy: 0.7071, Val Loss: 1.5242, Val Accuracy: 0.5574, Time: 73.40 seconds
# Epoch 80/100 - Train Loss: 0.8915, Train Accuracy: 0.7100, Val Loss: 1.5036, Val Accuracy: 0.5607, Time: 72.53 seconds
# Epoch 81/100 - Train Loss: 0.8795, Train Accuracy: 0.7128, Val Loss: 1.5146, Val Accuracy: 0.5660, Time: 72.98 seconds
# Epoch 82/100 - Train Loss: 0.8766, Train Accuracy: 0.7136, Val Loss: 1.5174, Val Accuracy: 0.5662, Time: 73.23 seconds
# Epoch 83/100 - Train Loss: 0.8733, Train Accuracy: 0.7158, Val Loss: 1.5047, Val Accuracy: 0.5720, Time: 72.78 seconds
# Epoch 84/100 - Train Loss: 0.8636, Train Accuracy: 0.7166, Val Loss: 1.5548, Val Accuracy: 0.5522, Time: 72.88 seconds
# Epoch 85/100 - Train Loss: 0.8673, Train Accuracy: 0.7189, Val Loss: 1.5223, Val Accuracy: 0.5691, Time: 73.06 seconds
# Epoch 86/100 - Train Loss: 0.8640, Train Accuracy: 0.7172, Val Loss: 1.4991, Val Accuracy: 0.5677, Time: 73.51 seconds
# Epoch 87/100 - Train Loss: 0.8575, Train Accuracy: 0.7205, Val Loss: 1.5271, Val Accuracy: 0.5597, Time: 72.66 seconds
# Epoch 88/100 - Train Loss: 0.8498, Train Accuracy: 0.7235, Val Loss: 1.5230, Val Accuracy: 0.5565, Time: 73.02 seconds
# Epoch 89/100 - Train Loss: 0.8441, Train Accuracy: 0.7245, Val Loss: 1.5047, Val Accuracy: 0.5745, Time: 73.29 seconds
# Epoch 90/100 - Train Loss: 0.8431, Train Accuracy: 0.7234, Val Loss: 1.5458, Val Accuracy: 0.5655, Time: 72.66 seconds
# Epoch 91/100 - Train Loss: 0.8361, Train Accuracy: 0.7284, Val Loss: 1.5215, Val Accuracy: 0.5728, Time: 73.73 seconds
# Epoch 92/100 - Train Loss: 0.8266, Train Accuracy: 0.7303, Val Loss: 1.5111, Val Accuracy: 0.5702, Time: 73.10 seconds
# Epoch 93/100 - Train Loss: 0.8271, Train Accuracy: 0.7304, Val Loss: 1.5032, Val Accuracy: 0.5706, Time: 73.80 seconds
# Epoch 94/100 - Train Loss: 0.8227, Train Accuracy: 0.7346, Val Loss: 1.5297, Val Accuracy: 0.5717, Time: 72.41 seconds
# Epoch 95/100 - Train Loss: 0.8184, Train Accuracy: 0.7305, Val Loss: 1.5472, Val Accuracy: 0.5643, Time: 74.10 seconds
# Epoch 96/100 - Train Loss: 0.8221, Train Accuracy: 0.7310, Val Loss: 1.5091, Val Accuracy: 0.5695, Time: 74.32 seconds
# Epoch 97/100 - Train Loss: 0.8080, Train Accuracy: 0.7380, Val Loss: 1.5379, Val Accuracy: 0.5705, Time: 74.58 seconds
# Epoch 98/100 - Train Loss: 0.8097, Train Accuracy: 0.7374, Val Loss: 1.5032, Val Accuracy: 0.5706, Time: 73.38 seconds
# Epoch 99/100 - Train Loss: 0.7966, Train Accuracy: 0.7409, Val Loss: 1.5010, Val Accuracy: 0.5750, Time: 74.23 seconds
# Epoch 100/100 - Train Loss: 0.7970, Train Accuracy: 0.7408, Val Loss: 1.5393, Val Accuracy: 0.5665, Time: 73.79 seconds
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Test Accuracy: 0.5657
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#               precision    recall  f1-score   support
#
#     airplane       0.56      0.71      0.62      1000
#   automobile       0.67      0.69      0.68      1000
#         bird       0.46      0.45      0.46      1000
#          cat       0.35      0.50      0.41      1000
#         deer       0.54      0.39      0.45      1000
#          dog       0.49      0.45      0.47      1000
#         frog       0.68      0.53      0.59      1000
#        horse       0.67      0.64      0.66      1000
#         ship       0.75      0.65      0.69      1000
#        truck       0.60      0.66      0.63      1000
#
#     accuracy                           0.57     10000
#    macro avg       0.58      0.57      0.57     10000
# weighted avg       0.58      0.57      0.57     10000
