# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from collections import defaultdict

import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.utils.data as data_utils
import torchvision
from torchvision import transforms

# Device Config
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Fix random seeds for reproducibility
seed = 73
torch.manual_seed(seed)
np.random.seed(seed)

# Load CIFAR-10 dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_data = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_data = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=128, shuffle=False)

n_classes = 10

# Define the Autoencoder Classifier model
class AutoencoderClassifier(nn.Module):
    def __init__(self, z_dim, n_classes):
        super(AutoencoderClassifier, self).__init__()
        # Encoder with Convolutional Layers
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 1024),
            nn.ReLU(True),
            nn.Linear(1024, z_dim)
        )
        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(z_dim, n_classes),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.classifier(z)

# Hyperparameters
z_dim = 256
epochs = 60
learning_rate = 1e-4

# Initialize the model
model = AutoencoderClassifier(z_dim=z_dim, n_classes=n_classes).to(device)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for X, y in train_loader:
        X, y = X.to(device), y.to(device)

        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += y.size(0)
        correct += predicted.eq(y).sum().item()

    train_losses.append(train_loss / len(train_loader))
    train_accuracies.append(100. * correct / total)

    # Validation
    model.eval()
    val_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for X, y in test_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total += y.size(0)
            correct += predicted.eq(y).sum().item()

    val_losses.append(val_loss / len(test_loader))
    val_accuracies.append(100. * correct / total)

    print(f'Epoch {epoch + 1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Train Acc: {train_accuracies[-1]:.2f}% | '
          f'Val Loss: {val_losses[-1]:.4f} | Val Acc: {val_accuracies[-1]:.2f}%')

# Plotting Loss and Accuracy
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# Visualizing Correct and Incorrect Predictions
model.eval()
correct_preds = []
incorrect_preds = []

with torch.no_grad():
    for X, y in test_loader:
        X, y = X.to(device), y.to(device)
        outputs = model(X)
        _, predicted = outputs.max(1)

        for i in range(X.size(0)):
            if predicted[i] == y[i]:
                correct_preds.append((X[i], predicted[i].item(), y[i].item()))
            else:
                incorrect_preds.append((X[i], predicted[i].item(), y[i].item()))

# Plot Correct Predictions
fig, axes = plt.subplots(2, 3, figsize=(10, 7))
fig.suptitle('Correct Predictions')

for i, ax in enumerate(axes.flatten()):
    img = correct_preds[i][0].cpu().permute(1, 2, 0).numpy()
    ax.imshow((img * 0.5) + 0.5)  # Unnormalize the image
    ax.set_title(f'Pred: {correct_preds[i][1]} | True: {correct_preds[i][2]}')
    ax.axis('off')

plt.show()

# Plot Incorrect Predictions
fig, axes = plt.subplots(2, 3, figsize=(10, 7))
fig.suptitle('Incorrect Predictions')

for i, ax in enumerate(axes.flatten()):
    img = incorrect_preds[i][0].cpu().permute(1, 2, 0).numpy()
    ax.imshow((img * 0.5) + 0.5)  # Unnormalize the image
    ax.set_title(f'Pred: {incorrect_preds[i][1]} | True: {incorrect_preds[i][2]}')
    ax.axis('off')

plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 54672643.09it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch 1/60 | Train Loss: 2.1245 | Train Acc: 33.55% | Val Loss: 2.0467 | Val Acc: 41.57%
# Epoch 2/60 | Train Loss: 2.0186 | Train Acc: 44.35% | Val Loss: 1.9971 | Val Acc: 46.75%
# Epoch 3/60 | Train Loss: 1.9770 | Train Acc: 48.56% | Val Loss: 1.9663 | Val Acc: 49.54%
# Epoch 4/60 | Train Loss: 1.9452 | Train Acc: 51.99% | Val Loss: 1.9312 | Val Acc: 53.23%
# Epoch 5/60 | Train Loss: 1.9174 | Train Acc: 54.86% | Val Loss: 1.9238 | Val Acc: 53.87%
# Epoch 6/60 | Train Loss: 1.8962 | Train Acc: 56.96% | Val Loss: 1.8905 | Val Acc: 57.40%
# Epoch 7/60 | Train Loss: 1.8751 | Train Acc: 59.09% | Val Loss: 1.8779 | Val Acc: 58.33%
# Epoch 8/60 | Train Loss: 1.8567 | Train Acc: 61.07% | Val Loss: 1.8641 | Val Acc: 59.99%
# Epoch 9/60 | Train Loss: 1.8412 | Train Acc: 62.62% | Val Loss: 1.8629 | Val Acc: 60.11%
# Epoch 10/60 | Train Loss: 1.8248 | Train Acc: 64.26% | Val Loss: 1.8475 | Val Acc: 61.64%
# Epoch 11/60 | Train Loss: 1.8131 | Train Acc: 65.47% | Val Loss: 1.8426 | Val Acc: 62.25%
# Epoch 12/60 | Train Loss: 1.7995 | Train Acc: 66.79% | Val Loss: 1.8414 | Val Acc: 62.37%
# Epoch 13/60 | Train Loss: 1.7894 | Train Acc: 67.92% | Val Loss: 1.8269 | Val Acc: 63.96%
# Epoch 14/60 | Train Loss: 1.7768 | Train Acc: 69.18% | Val Loss: 1.8145 | Val Acc: 65.16%
# Epoch 15/60 | Train Loss: 1.7667 | Train Acc: 70.18% | Val Loss: 1.8112 | Val Acc: 65.23%
# Epoch 16/60 | Train Loss: 1.7539 | Train Acc: 71.56% | Val Loss: 1.8033 | Val Acc: 66.37%
# Epoch 17/60 | Train Loss: 1.7451 | Train Acc: 72.33% | Val Loss: 1.8007 | Val Acc: 66.41%
# Epoch 18/60 | Train Loss: 1.7351 | Train Acc: 73.44% | Val Loss: 1.8038 | Val Acc: 65.84%
# Epoch 19/60 | Train Loss: 1.7265 | Train Acc: 74.29% | Val Loss: 1.7961 | Val Acc: 66.72%
# Epoch 20/60 | Train Loss: 1.7174 | Train Acc: 75.24% | Val Loss: 1.7889 | Val Acc: 67.54%
# Epoch 21/60 | Train Loss: 1.7067 | Train Acc: 76.35% | Val Loss: 1.7855 | Val Acc: 67.64%
# Epoch 22/60 | Train Loss: 1.6995 | Train Acc: 77.08% | Val Loss: 1.7819 | Val Acc: 68.16%
# Epoch 23/60 | Train Loss: 1.6896 | Train Acc: 78.04% | Val Loss: 1.7841 | Val Acc: 67.94%
# Epoch 24/60 | Train Loss: 1.6825 | Train Acc: 78.83% | Val Loss: 1.7828 | Val Acc: 68.09%
# Epoch 25/60 | Train Loss: 1.6744 | Train Acc: 79.51% | Val Loss: 1.7787 | Val Acc: 68.43%
# Epoch 26/60 | Train Loss: 1.6667 | Train Acc: 80.36% | Val Loss: 1.7756 | Val Acc: 68.73%
# Epoch 27/60 | Train Loss: 1.6613 | Train Acc: 80.90% | Val Loss: 1.7744 | Val Acc: 68.87%
# Epoch 28/60 | Train Loss: 1.6514 | Train Acc: 81.89% | Val Loss: 1.7698 | Val Acc: 69.40%
# Epoch 29/60 | Train Loss: 1.6454 | Train Acc: 82.41% | Val Loss: 1.7688 | Val Acc: 69.46%
# Epoch 30/60 | Train Loss: 1.6389 | Train Acc: 82.97% | Val Loss: 1.7700 | Val Acc: 69.24%
# Epoch 31/60 | Train Loss: 1.6352 | Train Acc: 83.41% | Val Loss: 1.7639 | Val Acc: 69.84%
# Epoch 32/60 | Train Loss: 1.6279 | Train Acc: 84.05% | Val Loss: 1.7649 | Val Acc: 69.48%
# Epoch 33/60 | Train Loss: 1.6240 | Train Acc: 84.46% | Val Loss: 1.7646 | Val Acc: 69.79%
# Epoch 34/60 | Train Loss: 1.6185 | Train Acc: 84.91% | Val Loss: 1.7633 | Val Acc: 69.89%
# Epoch 35/60 | Train Loss: 1.6136 | Train Acc: 85.27% | Val Loss: 1.7583 | Val Acc: 70.32%
# Epoch 36/60 | Train Loss: 1.6094 | Train Acc: 85.71% | Val Loss: 1.7613 | Val Acc: 69.99%
# Epoch 37/60 | Train Loss: 1.6067 | Train Acc: 85.98% | Val Loss: 1.7558 | Val Acc: 70.91%
# Epoch 38/60 | Train Loss: 1.6025 | Train Acc: 86.36% | Val Loss: 1.7556 | Val Acc: 70.76%
# Epoch 39/60 | Train Loss: 1.6007 | Train Acc: 86.53% | Val Loss: 1.7624 | Val Acc: 70.04%
# Epoch 40/60 | Train Loss: 1.5963 | Train Acc: 86.96% | Val Loss: 1.7572 | Val Acc: 70.38%
# Epoch 41/60 | Train Loss: 1.5939 | Train Acc: 87.17% | Val Loss: 1.7574 | Val Acc: 70.59%
# Epoch 42/60 | Train Loss: 1.5902 | Train Acc: 87.48% | Val Loss: 1.7597 | Val Acc: 70.35%
# Epoch 43/60 | Train Loss: 1.5894 | Train Acc: 87.55% | Val Loss: 1.7586 | Val Acc: 70.10%
# Epoch 44/60 | Train Loss: 1.5853 | Train Acc: 87.91% | Val Loss: 1.7525 | Val Acc: 70.95%
# Epoch 45/60 | Train Loss: 1.5834 | Train Acc: 88.09% | Val Loss: 1.7549 | Val Acc: 70.81%
# Epoch 46/60 | Train Loss: 1.5821 | Train Acc: 88.20% | Val Loss: 1.7557 | Val Acc: 70.69%
# Epoch 47/60 | Train Loss: 1.5806 | Train Acc: 88.31% | Val Loss: 1.7551 | Val Acc: 70.83%
# Epoch 48/60 | Train Loss: 1.5801 | Train Acc: 88.39% | Val Loss: 1.7533 | Val Acc: 70.77%
# Epoch 49/60 | Train Loss: 1.5764 | Train Acc: 88.71% | Val Loss: 1.7539 | Val Acc: 70.86%
# Epoch 50/60 | Train Loss: 1.5748 | Train Acc: 88.91% | Val Loss: 1.7515 | Val Acc: 71.11%
# Epoch 51/60 | Train Loss: 1.5736 | Train Acc: 89.00% | Val Loss: 1.7551 | Val Acc: 70.51%
# Epoch 52/60 | Train Loss: 1.5708 | Train Acc: 89.23% | Val Loss: 1.7546 | Val Acc: 70.81%
# Epoch 53/60 | Train Loss: 1.5715 | Train Acc: 89.20% | Val Loss: 1.7541 | Val Acc: 70.70%
# Epoch 54/60 | Train Loss: 1.5706 | Train Acc: 89.25% | Val Loss: 1.7515 | Val Acc: 71.15%
# Epoch 55/60 | Train Loss: 1.5689 | Train Acc: 89.41% | Val Loss: 1.7576 | Val Acc: 70.40%
# Epoch 56/60 | Train Loss: 1.5666 | Train Acc: 89.63% | Val Loss: 1.7537 | Val Acc: 70.72%
# Epoch 57/60 | Train Loss: 1.5655 | Train Acc: 89.72% | Val Loss: 1.7528 | Val Acc: 70.95%
# Epoch 58/60 | Train Loss: 1.5655 | Train Acc: 89.73% | Val Loss: 1.7509 | Val Acc: 71.10%
# Epoch 59/60 | Train Loss: 1.5640 | Train Acc: 89.87% | Val Loss: 1.7553 | Val Acc: 70.65%
# Epoch 60/60 | Train Loss: 1.5634 | Train Acc: 89.93% | Val Loss: 1.7474 | Val Acc: 71.34%
